# %%
from IPython.display import Image

# %% [markdown]
# # DALL. E
# https://openai.com/blog/dall-e/
#
# # Zero-Shot Text-to-Image Generation

# %%
Image('img/01.png')

# %% [markdown]
# ## 1. Abstract

# %%
Image('img/Abstact.jpg')

# %% [markdown]
# ## 2. Method

# %%
Image('img/method01.jpg')

# %%
Image('img/method02.jpg')

# %% [markdown]
# ### 2.1 Stage One

# %%
Image('img/stage1.jpg')

# %% [markdown]
# #### - d VAE([VQ-VAE:Neural Discrete Representation Learning](https://arxiv.org/abs/1711.00937) )

# %%
Image('img/vqvae.jpg')

# %% [markdown]
# ---
#
# #### - Gumbel softmax relaxation
# ([CATEGORICAL REPARAMETERIZATION WITH GUMBEL-SOFTMAX](https://arxiv.org/pdf/1611.01144.pdf))

# %%
Image('img/gumbel.jpg')

# %% [markdown]
# ### 2.2 Stage Two

# %%
Image('img/stage2.jpg')

# %%
Image('img/vqvae_result.jpg')

# %% [markdown]
# #### GPT-3

# %%
Image('img/gpt3.png')

# %% [markdown]
# #### Sparse transformer (sparse attention mask)

# %%
Image('img/sparseattentionmask.jpg')
